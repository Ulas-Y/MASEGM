# %%
# %load_ext autoreload
# %autoreload 2

# %%
import importlib
import main as main_mod
importlib.reload(main_mod)

from main import purinium_core_test
from engine.utils import plot_phase_map
from engine.utils.thermo_utils import print_phase_stats

#base_diffusion = 0.5       #default 0.5
#alpha = 1.0                #default 1.0
#energy_diffusion = 0.3     #default 0.3
#transport_strength = 0.3   #default 0.3 
k_strenght = 5.0
step_height = 2000
starter_step = 1
steps_amount = 2

worlds = []
steps_list = []
for d in range(1,steps_amount+1):
    steps_list.append("step " + str(d))    

for i, label in enumerate(steps_list, start=0):
    steps = starter_step + i*step_height
    w = main_mod.main(growth_k=k_strenght, steps=steps)
    worlds.append((label, w))

for label, w in worlds:
    print("=== ", label, " ===")
    print_phase_stats(w.mana.phase)
    plot_phase_map(w.mana.phase, title=f"{label} run: phases")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 25
#      23 for i, label in enumerate(steps_list, start=0):
#      24     steps = starter_step + i*step_height
# ---> 25     w = main_mod.main(growth_k=k_strenght, steps=steps)
#      26     worlds.append((label, w))
#      28 for label, w in worlds:
#
# File D:\OneDrive\Masaüstü\MAGI-SCI-PHYS-SYSTEM\main.py:83, in main(growth_k, steps)
#      79 diffusion_rate = base_diffusion * (1.0 + alpha * (1.0 - frac))
#      81 condense.set_entropy(S, S_max)
# ---> 83 world.step(cfg.dt)
#      85 max_dt_diffusion = 0.25 * (1.0 / C_MANA)  # CFL-like condition
#      86 effective_dt = min(cfg.dt, max_dt_diffusion)
#
# File D:\OneDrive\Masaüstü\MAGI-SCI-PHYS-SYSTEM\engine\world.py:49, in World.step(self, dt)
#      46     rule.apply(self.matter, dt)
#      48 for rule in self.interaction_rules:
# ---> 49     rule.apply(self.mana, self.matter, self.energy, dt)
#
# File D:\OneDrive\Masaüstü\MAGI-SCI-PHYS-SYSTEM\engine\rules\interaction_rules.py:44, in ManaCondensesToMatter.apply(self, mana, matter, energy, dt)
#      41 delta = rate * field * dt
#      43 mana.grid -= delta
# ---> 44 matter.grid += delta
#
# TypeError: Concatenation operation is not implemented for NumPy arrays, use np.concatenate() instead. Please do not rely on this error; it may not be given on all Python implementations.
