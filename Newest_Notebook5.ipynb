# %%
# %load_ext autoreload
# %autoreload 2

# %%
import importlib
import main as main_mod
importlib.reload(main_mod)

from main import purinium_core_test
from engine.utils import plot_phase_map
from engine.utils.thermo_utils import print_phase_stats

#base_diffusion = 0.5       #default 0.5
#alpha = 1.0                #default 1.0
#energy_diffusion = 0.3     #default 0.3
#transport_strength = 0.3   #default 0.3 
k_strenght = 1.0
step_height = 2000
starter_step = 1
steps_amount = 2

worlds = []
steps_list = []
for d in range(1,steps_amount+1):
    steps_list.append("step " + str(d))    

for i, label in enumerate(steps_list, start=0):
    steps = starter_step + i*step_height
    w = main_mod.main(growth_k=k_strenght, steps=steps)
    worlds.append((label, w))

for label, w in worlds:
    print("=== ", label, " ===")
    print_phase_stats(w.mana.phase)
    plot_phase_map(w.mana.phase, title=f"{label} run: phases")
# Out:
# Total mana: 0.11516822269740631
# Mana entropy (final): 9.210340371976178
# NESS check (last window):
#   Mana   -> is_ness=False, span=None, mean=None
#   Entropy-> is_ness=False, span=None, mean=None
# Mana entropy (min,max): 9.210340371976178, 9.210340371976178
# Total mana: 5.2890089597259406e+209
# Mana entropy (final): 2.387152829276459
# NESS check (last window):
#   Mana   -> is_ness=False, span=5.263447706484803e+209, mean=9.64677148159896e+208
#   Entropy-> is_ness=False, span=1.1387963836246309, mean=2.6945721384749866
# Mana entropy (min,max): 7.398052779211679e-07, 9.210340371976178
# ===  step 1  ===
# particles:      0  (  0.0%)
# plasma   :      0  (  0.0%)
# gas      :      0  (  0.0%)
# liquid   :      0  (  0.0%)
# aether   :   9999  (100.0%)
# purinium :      1  (  0.0%)
# total   : 10000
# ===  step 2  ===
# particles:   2539  ( 25.4%)
# plasma   :     17  (  0.2%)
# gas      :    295  (  2.9%)
# liquid   :   3371  ( 33.7%)
# aether   :   3728  ( 37.3%)
# ...

# %%
import importlib
import main as main_mod
importlib.reload(main_mod)

from main import purinium_core_test
from engine.utils import plot_phase_map
from engine.utils.thermo_utils import print_phase_stats

#base_diffusion = 0.5       #default 0.5
#alpha = 1.0                #default 1.0
#energy_diffusion = 0.3     #default 0.3
#transport_strength = 0.3   #default 0.3 
k_strenght = 1.0
step_height = 100
starter_step = 1
steps_amount = 10

worlds = []
steps_list = []
for d in range(1,steps_amount+1):
    steps_list.append("step " + str(d))    

for i, label in enumerate(steps_list, start=0):
    steps = starter_step + i*step_height
    w = main_mod.main(growth_k=k_strenght, steps=steps)
    worlds.append((label, w))

for label, w in worlds:
    print("=== ", label, " ===")
    print_phase_stats(w.mana.phase)
    plot_phase_map(w.mana.phase, title=f"{label} run: phases")
# Out:
# Total mana: 0.11516822269740631
# Mana entropy (final): 9.210340371976178
# NESS check (last window):
#   Mana   -> is_ness=False, span=None, mean=None
#   Entropy-> is_ness=False, span=None, mean=None
# Mana entropy (min,max): 9.210340371976178, 9.210340371976178
# Total mana: 48838807.7382237
# Mana entropy (final): 1.522097303068355
# NESS check (last window):
#   Mana   -> is_ness=False, span=47535976.57577721, mean=13665246.41211695
#   Entropy-> is_ness=False, span=1.5581111399999794, mean=1.2088436216687586
# Mana entropy (min,max): 7.398052779211679e-07, 9.210340371976178
# Total mana: 1.8662890992964284e+16
# Mana entropy (final): 1.448211021318954
# NESS check (last window):
#   Mana   -> is_ness=False, span=1.8208917118860932e+16, mean=5141337697237125.0
#   Entropy-> is_ness=False, span=1.1276483779393787, mean=1.5968292287603911
# Mana entropy (min,max): 7.398052779211679e-07, 9.210340371976178
# Total mana: 5.893344774388124e+24
# ...

# %%
import importlib
import main as main_mod
importlib.reload(main_mod)

from main import purinium_core_test
from engine.utils import plot_phase_map
from engine.utils.diagnostics import print_phase_stats

#base_diffusion = 0.5       #default 0.5
#alpha = 1.0                #default 1.0
#energy_diffusion = 0.3     #default 0.3
#transport_strength = 0.3   #default 0.3 
k_strenght = 0.0
step_height = 200
starter_step = 1
steps_amount = 5

worlds = []
steps_list = []
for d in range(1,steps_amount+1):
    steps_list.append("step " + str(d))    

for i, label in enumerate(steps_list, start=0):
    steps = starter_step + i*step_height
    w = main_mod.main(growth_k=k_strenght, steps=steps)
    worlds.append((label, w))

for label, w in worlds:
    print("=== ", label, " ===")
    print_phase_stats(w.mana.phase)
    plot_phase_map(w.mana.phase, title=f"{label} run: phases")

#this is the newest working method to test as 06/12/2025 and others are outdated or incompatible
# Out:
# Total mana: 0.10420851726531145
# Mana entropy (final): 9.210340371976178
# NESS check (last window):
#   Mana   -> is_ness=False, span=None, mean=None
#   Entropy-> is_ness=False, span=None, mean=None
# Mana entropy (min,max): 9.210340371976178, 9.210340371976178
# Total mana: 113818279.33619334
# Mana entropy (final): 1.9390083496453279
# NESS check (last window):
#   Mana   -> is_ness=False, span=80053027.2953534, mean=59626252.19091735
#   Entropy-> is_ness=False, span=1.2193430373032688, mean=1.5453973967697607
# Mana entropy (min,max): 4.797413469907367e-07, 9.210340371976178
# Total mana: 2.4976028064198e+16
# Mana entropy (final): 1.067611989852384
# NESS check (last window):
#   Mana   -> is_ness=False, span=2.072776550314198e+16, mean=1.147370569560142e+16
#   Entropy-> is_ness=False, span=0.7809869832495662, mean=1.5867082619721675
# Mana entropy (min,max): 4.797413469907367e-07, 9.210340371976178
# Total mana: 6.430499545641497e+24
# ...
