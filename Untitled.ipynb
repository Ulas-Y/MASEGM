# %%
from engine.fields.mana_field import ManaField
from engine.math.b_calculus import b_derivative

mana = ManaField(shape=(10, 10), initial_value=1.0)
print("Initial mean mana:", mana.grid.mean())

# apply B-scale power 2 (like ⊗ 2)
mana.b_scale_power(2.0)
print("After power 2, mean mana:", mana.grid.mean())

# test a simple B-derivative numerically on f(x) = x**3
f = lambda x: x**3
for x in [1.0, 2.0, 4.0]:
    print("D_B f at x =", x, "≈", b_derivative(f, x))
    # (should be close to e^3 ≈ 20.085)

mana = ManaField(shape=(10,10), initial_value=2.0)
mana.b_scale_power(3.0)
print(mana.grid.mean())
# Out:
# Initial mean mana: 1.0
# After power 2, mean mana: 1.0
# D_B f at x = 1.0 ≈ 20.08553681169055
# D_B f at x = 2.0 ≈ 20.085536923187668
# D_B f at x = 4.0 ≈ 20.0855387071418
# 8.0

# %%
import importlib
import main
importlib.reload(main)
from main import main as runmain          # import the module object



main(growth_k=0.0)
main(growth_k=1.0)
main(growth_k=2.0)
main(growth_k=5.0)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[70], line 3
#       1 import importlib
#       2 import main
# ----> 3 importlib.reload(main)
#       4 from main import main as runmain          # import the module object
#       8 main(growth_k=0.0)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\importlib\__init__.py:129, in reload(module)
#     127 if spec is None:
#     128     raise ModuleNotFoundError(f"spec not found for the module {name!r}", name=name)
# --> 129 _bootstrap._exec(spec, module)
#     130 # The module may have replaced itself in sys.modules!
#     131 return sys.modules[name]
#
# File <frozen importlib._bootstrap>:869, in _exec(spec, module)
#     867             spec.loader.load_module(name)
#     868         else:
# --> 869             spec.loader.exec_module(module)
#     870 finally:
#     871     # Update the order of insertion into sys.modules for module
#     872     # clean-up at shutdown.
#     873     module = sys.modules.pop(spec.name)
#
# File <frozen importlib._bootstrap_external>:762, in _LoaderBasics.exec_module(self, module)
#     759 if code is None:
#     760     raise ImportError(f'cannot load module {module.__name__!r} when '
#     761                       'get_code() returns None')
# --> 762 _bootstrap._call_with_frames_removed(exec, code, module.__dict__)
#
# File <frozen importlib._bootstrap>:491, in _call_with_frames_removed(f, *args, **kwds)
#     483 def _call_with_frames_removed(f, *args, **kwds):
#     484     """remove_importlib_frames in import.c will always remove sequences
#     485     of importlib frames that end with a call to this function
#     486
#    (...)    489     module code)
#     490     """
# --> 491     return f(*args, **kwds)
#
# File D:\OneDrive\Masaüstü\MAGI-SCI-PHYS-SYSTEM\main.py:7
#       5 from engine.rules.mana_rules import ConstantManaSource, BScaleManaGrowth
#       6 from engine.world import World
# ----> 7 from engine.utils import EngineConfig, plot_scalar_field, mana_entropy
#      10 def main(growth_k: float = 0.5, steps: int | None = None):
#      11     cfg = EngineConfig(ny=100, nx=100, dt=0.1, steps=100)
#
# ImportError: cannot import name 'mana_entropy' from 'engine.utils' (D:\OneDrive\Masaüstü\MAGI-SCI-PHYS-SYSTEM\engine\utils\__init__.py)
