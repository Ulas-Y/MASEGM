# %%
import importlib
import main
importlib.reload(main)
from main import main as runmain          # import the module object



runmain(growth_k=0.0)
runmain(growth_k=1.0)
runmain(growth_k=2.0)
runmain(growth_k=5.0)
# Out:
# Total mana: 10.000000009998997
# Mana entropy: 4.393073144027279
# Total mana: 23145.090801254562
# Mana entropy: 5.040093631594469
# Total mana: 267648931.87435263
# Mana entropy: 5.093977221710629
# Total mana: 1.317689893901861e+21
# Mana entropy: 5.124711076962814
