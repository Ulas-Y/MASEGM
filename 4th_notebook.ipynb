# %%
import importlib
import main as main_mod
importlib.reload(main_mod)

from engine.utils import plot_phase_map
from engine.utils.thermo_utils import print_phase_stats

#base_diffusion = 0.5       #default 0.5
#alpha = 1.0                #default 1.0
#energy_diffusion = 0.3     #default 0.3
#transport_strength = 0.3   #default 0.3 
k_strenght = 0.1
step_height = 100
starter_step = 1
steps_amount = 5

worlds = []
steps_list = []
for d in range(1,steps_amount+1):
    steps_list.append("step " + str(d))    

for i, label in enumerate(steps_list, start=0):
    steps = starter_step + i*step_height
    w = main_mod.main(growth_k=k_strenght, steps=steps)
    worlds.append((label, w))

for label, w in worlds:
    print("=== ", label, " ===")
    print_phase_stats(w.mana.phase)
    plot_phase_map(w.mana.phase, title=f"{label} run: phases")
# Out:
# Total mana: 0.10525583027542121
# Mana entropy (final): 9.210340371976184
# NESS check (last window):
#   Mana   -> is_ness=False, span=None, mean=None
#   Entropy-> is_ness=False, span=None, mean=None
# Mana entropy (min,max): 9.210340371976184, 9.210340371976184
# D:\OneDrive\Masaüstü\MAGI-SCI-PHYS-SYSTEM\engine\fields\mana_field.py:86: RuntimeWarning: overflow encountered in multiply
#   Fy = self.grid * vy
# D:\OneDrive\Masaüstü\MAGI-SCI-PHYS-SYSTEM\engine\fields\mana_field.py:87: RuntimeWarning: overflow encountered in multiply
#   Fx = self.grid * vx
# D:\OneDrive\Masaüstü\MAGI-SCI-PHYS-SYSTEM\engine\math\b_calculus.py:211: RuntimeWarning: overflow encountered in subtract
#   dFy_dy = 0.5 * (np.roll(Fy, -1, axis=0) - np.roll(Fy, 1, axis=0))
# D:\OneDrive\Masaüstü\MAGI-SCI-PHYS-SYSTEM\engine\math\b_calculus.py:212: RuntimeWarning: overflow encountered in subtract
#   dFx_dx = 0.5 * (np.roll(Fx, -1, axis=1) - np.roll(Fx, 1, axis=1))
# D:\OneDrive\Masaüstü\MAGI-SCI-PHYS-SYSTEM\engine\math\b_calculus.py:213: RuntimeWarning: invalid value encountered in add
#   return dFy_dy + dFx_dx
# D:\OneDrive\Masaüstü\MAGI-SCI-PHYS-SYSTEM\engine\fields\mana_field.py:86: RuntimeWarning: invalid value encountered in multiply
#   Fy = self.grid * vy
# D:\OneDrive\Masaüstü\MAGI-SCI-PHYS-SYSTEM\engine\fields\mana_field.py:87: RuntimeWarning: invalid value encountered in multiply
#   Fx = self.grid * vx
# Total mana: nan
# Mana entropy (final): nan
# NESS check (last window):
#   Mana   -> is_ness=False, span=nan, mean=nan
#   Entropy-> is_ness=False, span=nan, mean=nan
# Mana entropy (min,max): 5.977867109903507e-07, 9.210340371976184
# Total mana: nan
# Mana entropy (final): nan
# NESS check (last window):
#   Mana   -> is_ness=False, span=nan, mean=nan
#   Entropy-> is_ness=False, span=nan, mean=nan
# Mana entropy (min,max): 5.977867109903507e-07, 9.210340371976184
# Total mana: nan
# Mana entropy (final): nan
# NESS check (last window):
#   Mana   -> is_ness=False, span=nan, mean=nan
#   Entropy-> is_ness=False, span=nan, mean=nan
# Mana entropy (min,max): 5.977867109903507e-07, 9.210340371976184
# Total mana: nan
# Mana entropy (final): nan
# NESS check (last window):
#   Mana   -> is_ness=False, span=nan, mean=nan
#   Entropy-> is_ness=False, span=nan, mean=nan
# Mana entropy (min,max): 5.977867109903507e-07, 9.210340371976184
# ===  step 1  ===
# particles:      0  (  0.0%)
# plasma   :      0  (  0.0%)
# gas      :      0  (  0.0%)
# liquid   :      0  (  0.0%)
# aether   :   9999  (100.0%)
# purinium :      1  (  0.0%)
# total   : 10000
# ===  step 2  ===
# particles:  10000  (100.0%)
# plasma   :      0  (  0.0%)
# gas      :      0  (  0.0%)
# liquid   :      0  (  0.0%)
# aether   :      0  (  0.0%)
# purinium :      0  (  0.0%)
# total   : 10000
# ===  step 3  ===
# particles:  10000  (100.0%)
# plasma   :      0  (  0.0%)
# gas      :      0  (  0.0%)
# liquid   :      0  (  0.0%)
# aether   :      0  (  0.0%)
# purinium :      0  (  0.0%)
# total   : 10000
# ===  step 4  ===
# particles:  10000  (100.0%)
# plasma   :      0  (  0.0%)
# gas      :      0  (  0.0%)
# liquid   :      0  (  0.0%)
# aether   :      0  (  0.0%)
# purinium :      0  (  0.0%)
# total   : 10000
# ===  step 5  ===
# particles:  10000  (100.0%)
# plasma   :      0  (  0.0%)
# gas      :      0  (  0.0%)
# liquid   :      0  (  0.0%)
# aether   :      0  (  0.0%)
# purinium :      0  (  0.0%)
# total   : 10000
