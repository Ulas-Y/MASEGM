# %%
# %load_ext autoreload
# %autoreload 2

# %%
from main import main
main(growth_k=5.0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 2
#       1 from main import main
# ----> 2 main(growth_k=5.0)
#
# File D:\OneDrive\Masaüstü\MAGI-SCI-PHYS-SYSTEM\main.py:54, in main(growth_k, steps)
#      50 diffusion_rate = base_diffusion * (1.0 + alpha * (1.0 - frac))
#      52 condense.set_entropy(S, S_max)   # <-- pass entropy into the rule
# ---> 54 world.step(cfg.dt)
#      55 world.mana.diffuse(diffusion_rate, cfg.dt)
#      57 total_history.append(world.mana.total_mana())
#
# File D:\OneDrive\Masaüstü\MAGI-SCI-PHYS-SYSTEM\engine\world.py:30, in World.step(self, dt)
#      27     rule.apply(self.matter, dt)
#      29 for rule in self.interaction_rules:
# ---> 30     rule.apply(self.mana, self.matter, self.energy, dt)
#
# ...
