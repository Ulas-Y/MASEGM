# %%
# %load_ext autoreload
# %autoreload 2

# %%
from main import main
main(growth_k=5.0)
# Out:
# Total mana: 1.0005239643790846e+21
# Mana entropy (final): 5.522045060673406
# NESS check (last window):
#   Mana   -> is_ness=False, span=1.0004457646671905e+21, mean=1.2757574152092474e+20
#   Entropy-> is_ness=False, span=0.20228998932018616, mean=5.424378329716417
# Mana entropy (min,max): 0.0, 5.522045060673406

# %%
from main import main
main(growth_k=2.0)

# If you keep the world object around, or for a quick hack:
from engine.fields.mana_field import ManaField
import matplotlib.pyplot as plt

mana = ManaField(shape=(100,100), initial_value=0.0)  # example
# imagine mana.phase is filled by PhaseTransitionRule in a live run

plt.imshow(mana.phase, cmap="tab20")
plt.colorbar()
# Out:
# Total mana: 2489817491.4430246
# Mana entropy (final): 5.510301858738445
# NESS check (last window):
#   Mana   -> is_ness=False, span=2454721574.517349, mean=612410961.5053171
#   Entropy-> is_ness=False, span=0.2083780341599164, mean=5.409816102521557
# Mana entropy (min,max): 0.8463799874796532, 9.210340371976184

# %%
from main import main
main(growth_k=2.0)
# Out:
# Total mana: 2489817491.4430246
# Mana entropy (final): 5.510301858738445
# NESS check (last window):
#   Mana   -> is_ness=False, span=2454721574.517349, mean=612410961.5053171
#   Entropy-> is_ness=False, span=0.2083780341599164, mean=5.409816102521557
# Mana entropy (min,max): 0.8463799874796532, 9.210340371976184
