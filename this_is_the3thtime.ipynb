# %%
# %load_ext autoreload
# %autoreload 2

# %%
from main import main
main(growth_k=5.0)
# Out:
# Total mana: 588675340677861.1
# Mana entropy (final): 9.109138450871786
# NESS check (last window):
#   Mana   -> is_ness=False, span=588648997817646.6, mean=71815242036610.66
#   Entropy-> is_ness=False, span=0.06795328768374631, mean=9.079595365458447
# Mana entropy (min,max): 0.01861026521016211, 9.210340371976184

# %%
from main import main
main(growth_k=2.0)

# If you keep the world object around, or for a quick hack:
from engine.fields.mana_field import ManaField
import matplotlib.pyplot as plt

mana = ManaField(shape=(100,100), initial_value=0.0)  # example
# imagine mana.phase is filled by PhaseTransitionRule in a live run

plt.imshow(mana.phase, cmap="tab20")
plt.colorbar()
# Out:
# Total mana: 30.557542108366434
# Mana entropy (final): 7.774140893305895
# NESS check (last window):
#   Mana   -> is_ness=False, span=29.81210055516921, mean=8.073794577466634
#   Entropy-> is_ness=False, span=2.23120164706814, mean=6.855068317699311
# Mana entropy (min,max): 0.01607050396421622, 9.210340371976184

# %%
from main import main
main(growth_k=2.0)
# Out:
# Total mana: 30.557542108366434
# Mana entropy (final): 7.774140893305895
# NESS check (last window):
#   Mana   -> is_ness=False, span=29.81210055516921, mean=8.073794577466634
#   Entropy-> is_ness=False, span=2.23120164706814, mean=6.855068317699311
# Mana entropy (min,max): 0.01607050396421622, 9.210340371976184

# %%
from main import main

# compare behaviour
main(growth_k=0.0)   # no B-growth, just B-diffusion + sources
main(growth_k=1.0)
main(growth_k=2.0)
# Out:
# Total mana: 0.023718337387730673
# Mana entropy (final): 0.563316203289954
# NESS check (last window):
#   Mana   -> is_ness=False, span=0.0022075846871200296, mean=0.022635171832775712
#   Entropy-> is_ness=False, span=0.11625912947424649, mean=0.508922577006839
# Mana entropy (min,max): 0.03267077424747213, 9.210340371976184
# Total mana: 0.050554941046782285
# Mana entropy (final): 1.2236502160461338
# NESS check (last window):
#   Mana   -> is_ness=False, span=0.01465407420728014, mean=0.04238385419080894
#   Entropy-> is_ness=False, span=0.3862621812044077, mean=1.0137750038529334
# Mana entropy (min,max): 0.03266650797850069, 9.210340371976184
# Total mana: 30.557542108366434
# Mana entropy (final): 7.774140893305895
# NESS check (last window):
#   Mana   -> is_ness=False, span=29.81210055516921, mean=8.073794577466634
#   Entropy-> is_ness=False, span=2.23120164706814, mean=6.855068317699311
# Mana entropy (min,max): 0.01607050396421622, 9.210340371976184

# %%
from main import main

# no B-growth, only energy-coupled rule
main(growth_k=0.0)

# plus your original B-scale mana growth on top
main(growth_k=1.0)
main(growth_k=2.0)
main(growth_k=3.0)
main(growth_k=5.0)
main(growth_k=10.0)
# Out:
# Total mana: 0.023718337387730673
# Mana entropy (final): 0.563316203289954
# NESS check (last window):
#   Mana   -> is_ness=False, span=0.0022075846871200296, mean=0.022635171832775712
#   Entropy-> is_ness=False, span=0.11625912947424649, mean=0.508922577006839
# Mana entropy (min,max): 0.03267077424747213, 9.210340371976184
# Total mana: 0.050554941046782285
# Mana entropy (final): 1.2236502160461338
# NESS check (last window):
#   Mana   -> is_ness=False, span=0.01465407420728014, mean=0.04238385419080894
#   Entropy-> is_ness=False, span=0.3862621812044077, mean=1.0137750038529334
# Mana entropy (min,max): 0.03266650797850069, 9.210340371976184
# Total mana: 30.557542108366434
# Mana entropy (final): 7.774140893305895
# NESS check (last window):
#   Mana   -> is_ness=False, span=29.81210055516921, mean=8.073794577466634
#   Entropy-> is_ness=False, span=2.23120164706814, mean=6.855068317699311
# Mana entropy (min,max): 0.01607050396421622, 9.210340371976184
# ...

# %%
from main import main

# no B-growth, only energy-coupled rule
main(growth_k=0.0)

# plus your original B-scale mana growth on top
main(growth_k=1.0, steps=200)
main(growth_k=2.0, steps=100)
main(growth_k=3.0, steps=1000)
main(growth_k=5.0, steps=150)
main(growth_k=10.0, steps=300)
# Out:
# Total mana: 0.023718337387730673
# Mana entropy (final): 0.563316203289954
# NESS check (last window):
#   Mana   -> is_ness=False, span=0.0022075846871200296, mean=0.022635171832775712
#   Entropy-> is_ness=False, span=0.11625912947424649, mean=0.508922577006839
# Mana entropy (min,max): 0.03267077424747213, 9.210340371976184
# Total mana: 49.44472674082266
# Mana entropy (final): 7.689027234562246
# NESS check (last window):
#   Mana   -> is_ness=False, span=43.532854627027106, mean=20.633370187765113
#   Entropy-> is_ness=False, span=0.7788286383723575, mean=7.336432626786758
# Mana entropy (min,max): 0.03266650797850069, 9.210340371976184
# Total mana: 30.557542108366434
# Mana entropy (final): 7.774140893305895
# NESS check (last window):
#   Mana   -> is_ness=False, span=29.81210055516921, mean=8.073794577466634
#   Entropy-> is_ness=False, span=2.23120164706814, mean=6.855068317699311
# Mana entropy (min,max): 0.01607050396421622, 9.210340371976184
# ...

# %%
from main import main

main(growth_k=0.0)
main(growth_k=0.0, steps=200)
main(growth_k=0.0, steps=500)
main(growth_k=0.0, steps=1000)
main(growth_k=0.0, steps=5000)
main(growth_k=0.0, steps=10000)
# Out:
# Total mana: 0.023718337387730673
# Mana entropy (final): 0.563316203289954
# NESS check (last window):
#   Mana   -> is_ness=False, span=0.0022075846871200296, mean=0.022635171832775712
#   Entropy-> is_ness=False, span=0.11625912947424649, mean=0.508922577006839
# Mana entropy (min,max): 0.03267077424747213, 9.210340371976184
# Total mana: 0.03279475679102951
# Mana entropy (final): 0.8991921007354131
# NESS check (last window):
#   Mana   -> is_ness=False, span=0.0009317859670220849, mean=0.032349075914647335
#   Entropy-> is_ness=False, span=0.03130909454408348, mean=0.884259374125002
# Mana entropy (min,max): 0.03267077424747213, 9.210340371976184
# Total mana: 0.038132289801596976
# Mana entropy (final): 1.0688155778087207
# NESS check (last window):
#   Mana   -> is_ness=False, span=0.00016452417109867612, mean=0.038050874231317415
#   Entropy-> is_ness=False, span=0.005000841386121113, mean=1.0663419378635142
# Mana entropy (min,max): 0.03267077424747213, 9.210340371976184
# ...

# %%
from main import main

main(growth_k=1.0)
main(growth_k=1.0, steps=200)
main(growth_k=1.0, steps=500)
main(growth_k=1.0, steps=1000)
main(growth_k=1.0, steps=5000)
main(growth_k=1.0, steps=10000)
# Out:
# Total mana: 0.050554941046782285
# Mana entropy (final): 1.2236502160461338
# NESS check (last window):
#   Mana   -> is_ness=False, span=0.01465407420728014, mean=0.04238385419080894
#   Entropy-> is_ness=False, span=0.3862621812044077, mean=1.0137750038529334
# Mana entropy (min,max): 0.03266650797850069, 9.210340371976184
# Total mana: 49.44472674082266
# Mana entropy (final): 7.689027234562246
# NESS check (last window):
#   Mana   -> is_ness=False, span=43.532854627027106, mean=20.633370187765113
#   Entropy-> is_ness=False, span=0.7788286383723575, mean=7.336432626786758
# Mana entropy (min,max): 0.03266650797850069, 9.210340371976184
# Total mana: 8.2957845854455e+17
# Mana entropy (final): 9.067416782176869
# NESS check (last window):
#   Mana   -> is_ness=False, span=7.539976129254825e+17, mean=3.219988116333714e+17
#   Entropy-> is_ness=False, span=0.011327204932230828, mean=9.061869802667237
# Mana entropy (min,max): 0.03266650797850069, 9.210340371976184
# ...

# %%
from main import main
main(growth_k=2.0, steps=100)

# If you keep the world object around, or for a quick hack:
from engine.fields.mana_field import ManaField
import matplotlib.pyplot as plt

mana = ManaField(shape=(100,100), initial_value=0.0)  # example
# imagine mana.phase is filled by PhaseTransitionRule in a live run

plt.imshow(mana.phase, cmap="tab20")
plt.colorbar()
# Out:
# Total mana: 30.557542108366434
# Mana entropy (final): 7.774140893305895
# NESS check (last window):
#   Mana   -> is_ness=False, span=29.81210055516921, mean=8.073794577466634
#   Entropy-> is_ness=False, span=2.23120164706814, mean=6.855068317699311
# Mana entropy (min,max): 0.01607050396421622, 9.210340371976184

# %%
from main import main
main(growth_k=2.0, steps=1000)

# If you keep the world object around, or for a quick hack:
from engine.fields.mana_field import ManaField
import matplotlib.pyplot as plt

mana = ManaField(shape=(100,100), initial_value=0.0)  # example
# imagine mana.phase is filled by PhaseTransitionRule in a live run

plt.imshow(mana.phase, cmap="tab20")
plt.colorbar()
# Out:
# Total mana: 1.6344432765111524e+90
# Mana entropy (final): 9.199287014460873
# NESS check (last window):
#   Mana   -> is_ness=False, span=1.612764864453844e+90, mean=3.97364364316115e+89
#   Entropy-> is_ness=True, span=0.00030542615075113133, mean=9.199135456689447
# Mana entropy (min,max): 0.01607050396421622, 9.210340371976184

# %%
from main import main

main(growth_k=0.0, steps=200)
# Out:
# Total mana: 0.6976460112494385
# Mana entropy (final): 3.627747311116874
# NESS check (last window):
#   Mana   -> is_ness=False, span=0.16549837012220914, mean=0.6116842761056048
#   Entropy-> is_ness=False, span=0.1889686989497612, mean=3.534871838728879
# Mana entropy (min,max): 0.039648759602836876, 9.210340371976184

# %%
from main import main
main(growth_k=1.0, steps=400)
# Out:
# Total mana: 2.120714494873183e+24
# Mana entropy (final): 4.061186497631002
# NESS check (last window):
#   Mana   -> is_ness=False, span=2.0420202189352104e+24, mean=6.434665049131213e+23
#   Entropy-> is_ness=False, span=0.008562991996583058, mean=4.0561143049429775
# Mana entropy (min,max): 0.03964381426867334, 9.210340371976184

# %%
from main import main
main(growth_k=2.0, steps=400)
# Out:
# Total mana: 8.401538901614255e+41
# Mana entropy (final): 4.031389012620801
# NESS check (last window):
#   Mana   -> is_ness=False, span=8.355021839129714e+41, mean=1.7434362959913813e+41
#   Entropy-> is_ness=True, span=0.001410695432773501, mean=4.0306144852326415
# Mana entropy (min,max): 0.03640047434605966, 9.210340371976184

# %%
from main import main
#base_diffusion = 0.5
#alpha = 1.0
#energy_diffusion = 0.3
#transport_strength = 0.5
main(growth_k=0.0, steps=400)
main(growth_k=1.0, steps=400)
main(growth_k=2.0, steps=400)
# Out:
# Total mana: 108.55595912021633
# Mana entropy (final): 5.257495924043782
# NESS check (last window):
#   Mana   -> is_ness=False, span=47.65578399931522, mean=81.98814562040728
#   Entropy-> is_ness=False, span=0.054300854439359725, mean=5.228366072573842
# Mana entropy (min,max): 0.04368222867221832, 9.210340371976184
# Total mana: 9.070209345851807e+24
# Mana entropy (final): 4.439603655594222
# NESS check (last window):
#   Mana   -> is_ness=False, span=8.73469737474449e+24, mean=2.752116922415307e+24
#   Entropy-> is_ness=False, span=0.006745688307547404, mean=4.435184749095428
# Mana entropy (min,max): 0.04367689788802162, 9.210340371976184
# Total mana: 6.260435512351211e+42
# Mana entropy (final): 4.547598680852467
# NESS check (last window):
#   Mana   -> is_ness=False, span=6.225678680217172e+42, mean=1.3042832069596666e+42
#   Entropy-> is_ness=False, span=0.02395359964821253, mean=4.53555491812442
# Mana entropy (min,max): 0.043676897888014224, 9.210340371976184

# %%
from main import main
#base_diffusion = 0.5
#alpha = 1.0
#energy_diffusion = 0.5
#transport_strength = 0.3
main(growth_k=0.0, steps=400)
main(growth_k=1.0, steps=400)
main(growth_k=2.0, steps=400)
# Out:
# Total mana: 14178.445587478423
# Mana entropy (final): 4.089916503010779
# NESS check (last window):
#   Mana   -> is_ness=False, span=10513.574260966021, mean=7800.509245500648
#   Entropy-> is_ness=False, span=0.04284566564534309, mean=4.108979122290728
# Mana entropy (min,max): 0.039648759602836876, 9.210340371976184
# Total mana: 1.450989201017806e+27
# Mana entropy (final): 4.133754668485475
# NESS check (last window):
#   Mana   -> is_ness=False, span=1.413707526516799e+27, mean=4.0420825351323525e+26
#   Entropy-> is_ness=False, span=0.024638190154623985, mean=4.120909076559212
# Mana entropy (min,max): 0.03964381426867334, 9.210340371976184
# Total mana: 3.7524495822557265e+44
# Mana entropy (final): 4.078822248666712
# NESS check (last window):
#   Mana   -> is_ness=False, span=3.737512412506209e+44, mean=7.39359725411333e+43
#   Entropy-> is_ness=False, span=0.015175749261501892, mean=4.070383965723975
# Mana entropy (min,max): 0.03614630397212626, 9.210340371976184

# %%
from main import main
#base_diffusion = 0.5
#alpha = 1.2
#energy_diffusion = 0.3
#transport_strength = 0.3
main(growth_k=0.0, steps=400)
main(growth_k=1.0, steps=400)
main(growth_k=2.0, steps=400)
# Out:
# Total mana: 8.105091478677297
# Mana entropy (final): 4.740811248130353
# NESS check (last window):
#   Mana   -> is_ness=False, span=2.0874772034779863, mean=7.002774422992819
#   Entropy-> is_ness=False, span=0.06534251874445829, mean=4.708967261807812
# Mana entropy (min,max): 0.039648759602836876, 9.210340371976184
# Total mana: 1.2328997582165038e+24
# Mana entropy (final): 4.069036688765989
# NESS check (last window):
#   Mana   -> is_ness=False, span=1.1856874224086076e+24, mean=3.768828105453479e+23
#   Entropy-> is_ness=True, span=0.003021759926546075, mean=4.066854599840822
# Mana entropy (min,max): 0.03964381426867334, 9.210340371976184
# Total mana: 4.602336718750029e+41
# Mana entropy (final): 4.047289665333103
# NESS check (last window):
#   Mana   -> is_ness=False, span=4.575030382031878e+41, mean=9.659404395324026e+40
#   Entropy-> is_ness=False, span=0.010959515406759657, mean=4.051977125652881
# Mana entropy (min,max): 0.03964381426866641, 9.210340371976184

# %%
from main import main
#base_diffusion = 0.7
#alpha = 1.0
#energy_diffusion = 0.3
#transport_strength = 0.3
main(growth_k=0.0, steps=400)
main(growth_k=1.0, steps=400)
main(growth_k=2.0, steps=400)
# Out:
# Total mana: 1.1052569116934077
# Mana entropy (final): 4.407459779345355
# NESS check (last window):
#   Mana   -> is_ness=False, span=0.14183499736906313, mean=1.032818744001624
#   Entropy-> is_ness=False, span=0.07622451325907686, mean=4.36966587060943
# Mana entropy (min,max): 0.021228862160356767, 9.210340371976184
# Total mana: 1.8464597004120781e+22
# Mana entropy (final): 4.253001560576108
# NESS check (last window):
#   Mana   -> is_ness=False, span=1.7490560034012832e+22, mean=6.141076640534408e+21
#   Entropy-> is_ness=False, span=0.03885828598903451, mean=4.2721859742820465
# Mana entropy (min,max): 0.02122504244932772, 9.210340371976184
# Total mana: 1.9473189281651714e+40
# Mana entropy (final): 4.570046661788561
# NESS check (last window):
#   Mana   -> is_ness=False, span=1.930149309952301e+40, mean=4.3914221105933906e+39
#   Entropy-> is_ness=False, span=0.011683908376275198, mean=4.576405947887517
# Mana entropy (min,max): 0.021225042449324556, 9.210340371976184

# %%
from main import main
#base_diffusion = 0.5
#alpha = 0.8
#energy_diffusion = 0.3
#transport_strength = 0.3
main(growth_k=0.0, steps=400)
main(growth_k=1.0, steps=400)
main(growth_k=2.0, steps=400)
# Out:
# Total mana: 34.9279580824988
# Mana entropy (final): 4.747739553877939
# NESS check (last window):
#   Mana   -> is_ness=False, span=13.118638725193751, mean=27.785733293222016
#   Entropy-> is_ness=False, span=0.03693685717219264, mean=4.729901573304675
# Mana entropy (min,max): 0.039648759602836876, 9.210340371976184
# Total mana: 3.296315429852022e+24
# Mana entropy (final): 4.054546552673513
# NESS check (last window):
#   Mana   -> is_ness=False, span=3.1760569646507663e+24, mean=9.964391793272514e+23
#   Entropy-> is_ness=False, span=0.012952605962351704, mean=4.047331013999363
# Mana entropy (min,max): 0.03964381426867334, 9.210340371976184
# Total mana: 1.4010672916540233e+42
# Mana entropy (final): 4.027577136845215
# NESS check (last window):
#   Mana   -> is_ness=False, span=1.3936874962183966e+42, mean=2.8848761352922224e+41
#   Entropy-> is_ness=False, span=0.00894102736481095, mean=4.022283224576287
# Mana entropy (min,max): 0.03323281931051006, 9.210340371976184

# %%
from main import main
#base_diffusion = 0.3
#alpha = 1.0
#energy_diffusion = 0.3
#transport_strength = 0.3
main(growth_k=0.0, steps=400)
main(growth_k=1.0, steps=400)
main(growth_k=2.0, steps=400)
# Out:
# Total mana: 1237.7117173089403
# Mana entropy (final): 4.385176803123976
# NESS check (last window):
#   Mana   -> is_ness=False, span=587.244300078375, mean=918.300783445637
#   Entropy-> is_ness=False, span=0.06834518490219921, mean=4.419247334259843
# Mana entropy (min,max): 0.07336224208493983, 9.210340371976184
# Total mana: 1.2034893240222758e+24
# Mana entropy (final): 4.239270829524398
# NESS check (last window):
#   Mana   -> is_ness=False, span=1.145711664216884e+24, mean=3.8990536654950104e+23
#   Entropy-> is_ness=False, span=0.014982477204642741, mean=4.246205395255176
# Mana entropy (min,max): 0.0733570529394926, 9.210340371976184
# Total mana: 4.941223235413055e+42
# Mana entropy (final): 4.12418759533459
# NESS check (last window):
#   Mana   -> is_ness=False, span=4.911647339494749e+42, mean=1.0414354335531453e+42
#   Entropy-> is_ness=False, span=0.017472493083854346, mean=4.11506603985756
# Mana entropy (min,max): 0.07335705293947842, 9.210340371976184

# %%
from main import main
#base_diffusion = 0.5
#alpha = 1.0
#energy_diffusion = 0.3
#transport_strength = 0.15
main(growth_k=0.0, steps=400)
main(growth_k=1.0, steps=400)
main(growth_k=2.0, steps=400)
# Out:
# Total mana: 1.5298692650849297
# Mana entropy (final): 3.911948118275001
# NESS check (last window):
#   Mana   -> is_ness=False, span=0.2633974020442098, mean=1.3935462184506515
#   Entropy-> is_ness=False, span=0.09023096763709981, mean=3.8672688473402035
# Mana entropy (min,max): 0.03641149666159562, 9.210340371976184
# Total mana: 6.414318328430322e+22
# Mana entropy (final): 3.935831911145083
# NESS check (last window):
#   Mana   -> is_ness=False, span=6.130894178059933e+22, mean=2.0434418587741165e+22
#   Entropy-> is_ness=False, span=0.010153413156796187, mean=3.941217215989693
# Mana entropy (min,max): 0.036406863492666613, 9.210340371976184
# Total mana: 1.531703057482517e+41
# Mana entropy (final): 3.935187038249367
# NESS check (last window):
#   Mana   -> is_ness=False, span=1.5230892430481767e+41, mean=3.202587535476304e+40
#   Entropy-> is_ness=True, span=0.001118566498419682, mean=3.9359993267904847
# Mana entropy (min,max): 0.029133119364641073, 9.210340371976184

# %%
from main import main
#base_diffusion = 0.5
#alpha = 1.0
#energy_diffusion = 0.3
#transport_strength = 0.3
main(growth_k=0.0, steps=200)
main(growth_k=1.0, steps=400)
main(growth_k=2.0, steps=400)
main(growth_k=1.0, steps=1000)
main(growth_k=2.0, steps=1000)
# Out:
# Total mana: 0.6976460112494385
# Mana entropy (final): 3.627747311116874
# NESS check (last window):
#   Mana   -> is_ness=False, span=0.16549837012220914, mean=0.6116842761056048
#   Entropy-> is_ness=False, span=0.1889686989497612, mean=3.534871838728879
# Mana entropy (min,max): 0.039648759602836876, 9.210340371976184
# Total mana: 2.120714494873183e+24
# Mana entropy (final): 4.061186497631002
# NESS check (last window):
#   Mana   -> is_ness=False, span=2.0420202189352104e+24, mean=6.434665049131213e+23
#   Entropy-> is_ness=False, span=0.008562991996583058, mean=4.0561143049429775
# Mana entropy (min,max): 0.03964381426867334, 9.210340371976184
# Total mana: 8.401538901614255e+41
# Mana entropy (final): 4.031389012620801
# NESS check (last window):
#   Mana   -> is_ness=False, span=8.355021839129714e+41, mean=1.7434362959913813e+41
#   Entropy-> is_ness=True, span=0.001410695432773501, mean=4.0306144852326415
# Mana entropy (min,max): 0.03640047434605966, 9.210340371976184
# ...
